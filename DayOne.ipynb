# %%
import os

# %%
os.listdir('mats')
# Out:
# ['2023-nwbc-data.csv',
#  '2023-nwbc-raw-data.csv',
#  '2023-nwbc-reds.csv',
#  'nw-version-reds.xlsx',
#  '2023-nwbc-reds.xlsx']

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
x =1 
y = 2

# %%
print(x + y)
# Out:
# 3

# %%
# opening the dataframe (the dataset .csv)
df = pd.read_csv('mats/2023-nwbc-reds.csv')

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    post_bat_score  post_fld_score  if_fielding_alignment  \
# 0               2              15               Standard
# ...

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'pitcher_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
df['away_score']
# there is a not a df.[ ]  it is just df['column name']
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
#          ..
# 49033     0
# 49034     0
# 49035     0
# 49036     0
# 49037     0
# Name: away_score, Length: 49038, dtype: int64

# %%
df['home_score'] + df['away_score']
# Out:
# 0        17
# 1        17
# 2        17
# 3        17
# 4        17
#          ..
# 49033     0
# 49034     0
# 49035     0
# 49036     0
# 49037     0
# Length: 49038, dtype: int64

# %%
df['total_score'] = df['home_score'] + df['away_score']
# you simply state the column name you would like to add in the predetermined list.
# set it to equal the additoin of columns youd like to combine to make a new feature.

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    post_fld_score  if_fielding_alignment  of_fielding_alignment  spin_axis  \
# ...

# %%
df['description'].unique()
# dont for get the () at the end of the method.
# Out:
# array(['hit_into_play', 'ball', 'called_strike', 'swinging_strike',
#        'foul', 'blocked_ball', 'swinging_strike_blocked', 'hit_by_pitch',
#        'foul_tip', 'foul_bunt', 'missed_bunt', 'bunt_foul_tip',
#        'pitchout'], dtype=object)

# %%
strike_events = ['called_strike', 'swinging_strike','foul', 'swinging_strike_blocked','foul_tip', 'foul_bunt', 'missed_bunt', 'bunt_foul_tip']
# this is a list you created as strike events.

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    post_fld_score  if_fielding_alignment  of_fielding_alignment  spin_axis  \
# ...

# %%
# loc method to locating information based on if statements
df.loc[df['description']=='foul']
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 9             SI  2022-10-05           93.4           2.36           5.41
# 16            FC  2022-10-05           88.1          -3.07           5.74
# 28            FF  2022-10-05           95.1          -0.71           5.91
# 40            SI  2022-10-05           89.8           3.32           5.04
# 59            FF  2022-10-05           96.0          -1.93           5.61
# ...          ...         ...            ...            ...            ...
# 48979        NaN  2022-03-31            NaN            NaN            NaN
# 48982        NaN  2022-03-31            NaN            NaN            NaN
# 49018        NaN  2022-03-31            NaN            NaN            NaN
# 49028        NaN  2022-03-31            NaN            NaN            NaN
# 49033        NaN  2022-03-31            NaN            NaN            NaN
#
#              pitcher_name  batter  pitcher events description  ...  \
# ...

# %%
df.loc[df['description'].isin(strike_events)]
# using the .isin method to call a list that was created.
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 3             FF  2022-10-05           93.8           2.32           5.48
# 4             FF  2022-10-05           94.1           2.34           5.54
# 6             FF  2022-10-05           94.5           2.25           5.47
# 9             SI  2022-10-05           93.4           2.36           5.41
# 12            FF  2022-10-05           92.7           2.45           5.40
# ...          ...         ...            ...            ...            ...
# 49033        NaN  2022-03-31            NaN            NaN            NaN
# 49034        NaN  2022-03-31            NaN            NaN            NaN
# 49035        NaN  2022-03-31            NaN            NaN            NaN
# 49036        NaN  2022-03-31            NaN            NaN            NaN
# 49037        NaN  2022-03-31            NaN            NaN            NaN
#
#           pitcher_name  batter  pitcher     events      description  ...  \
# ...

# %%
df['is_strike'] = 0
# The above creates another new column and sets the value to 0

df.loc[df['description'].isin(strike_events), 'is_strike'] = 1
# changes the column to show is_strike column all 0, but, using the created list whenever that 
# strike is true, the value then is set to one.
# pandas if statment?

# %%
df['is_strike']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 49033    1
# 49034    1
# 49035    1
# 49036    1
# 49037    1
# Name: is_strike, Length: 49038, dtype: int64

# %%
df.head(9)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
# 5         FF  2022-10-05           93.8           2.33           5.50
# 6         FF  2022-10-05           94.5           2.25           5.47
# 7         FF  2022-10-05           92.8           2.48           5.40
# 8         FF  2022-10-05           94.7           2.32           5.55
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# ...

# %%
df['is_2_strikes'] = 0
df.loc[df['strikes']==2, 'is_2_strikes'] = 1

# %%
df.loc[df['is_2_strikes'] == 1]
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0             FF  2022-10-05           93.8           2.39           5.44
# 1             FF  2022-10-05           93.3           2.30           5.51
# 2             SL  2022-10-05           84.3           2.45           5.21
# 7             FF  2022-10-05           92.8           2.48           5.40
# 8             FF  2022-10-05           94.7           2.32           5.55
# ...          ...         ...            ...            ...            ...
# 49023        NaN  2022-03-31            NaN            NaN            NaN
# 49026        NaN  2022-03-31            NaN            NaN            NaN
# 49027        NaN  2022-03-31            NaN            NaN            NaN
# 49032        NaN  2022-03-31            NaN            NaN            NaN
# 49035        NaN  2022-03-31            NaN            NaN            NaN
#
#           pitcher_name  batter  pitcher     events      description  ...  \
# ...

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-05           93.8           2.39           5.44
# 1         FF  2022-10-05           93.3           2.30           5.51
# 2         SL  2022-10-05           84.3           2.45           5.21
# 3         FF  2022-10-05           93.8           2.32           5.48
# 4         FF  2022-10-05           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...  \
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    of_fielding_alignment  spin_axis  delta_home_win_exp  delta_run_exp  \
# ...

# %% [markdown]
# ## Home Work
#
# 1. use the "strikes" column to find where there are 2 strikes and make a new column
# indicating whether the pitch was thrown in a 2 strike situation.
#
# Name this column: is_2_strikes
#
#
# 2. use the release speend column to find when a pitch is thrown greater than 94 MPH
# The column is in MPH already,
#
# Name this: is_high_velo
#
#
# 3. us the description column AND the attack_zone column to indicate when a pitch is thrown for a called or swinging
# strike  (not a foul) in the "heart" attack zone.
# This requires two conditional statements
# ask google or discord.
